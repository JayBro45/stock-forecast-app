# %%
import sys
import os
import pandas as pd

# %%
# Add project root to sys.path
sys.path.append(os.path.abspath(".."))

from src.utils.logger import evaluate_all_models

# %%
df = pd.read_csv("../data/processed/MSFT_clean.csv", parse_dates=["Date"])

# %%
split_idx = -30
train = df.iloc[:split_idx].copy()
test = df.iloc[split_idx:].copy()

# %%
results_df = evaluate_all_models(train, test, save_dir="../src/models/metrics")
# Out:
# ⚡ Running Naive Baseline...
# 💾 Model saved at: ../src/models/metrics\naive_baseline\naive_baseline_model.pkl
# ✅ Done Naive Baseline | MAE: 8.8227, RMSE: 10.4351
#
# ⚡ Running ARIMA...
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 96.064% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - B
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# 💾 ARIMA model saved at: ../src/models/metrics\arima\arima_model.pkl
# ✅ Done ARIMA | MAE: 9.5879, RMSE: 11.3069
#
# ⚡ Running NeuralProphet...
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (61) is too small than the required number                     for the learning rate finder (232). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/232 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 96.064% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - B
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 96.667% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - B
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 96.667% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - B
# Predicting: 61it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# 💾 Model saved at: ../src/models/metrics\neuralprophet\neuralprophet_model.pkl
# ✅ Done NeuralProphet | MAE: 40.4876, RMSE: 41.6794
#
# ⚡ Running XGBoost...
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 results_df = evaluate_all_models(train, test, save_dir="../src/models/metrics")
#
# File c:\My Stuff\Projects\Stock Forecast App\stock-forecast-app\src\utils\logger.py:56, in evaluate_all_models(train_df, test_df, save_dir)
#      53 print(f"✅ Done NeuralProphet | MAE: {metrics_prophet['MAE']:.4f}, RMSE: {metrics_prophet['RMSE']:.4f}")
#      55 print("\n⚡ Running XGBoost...")
# ---> 56 _, _, metrics_xgb = XGBoostModel(train_df, test_df, save_dir=model_dir("xgboost"))
#      57 results["XGBoost"] = metrics_xgb
#      58 print(f"✅ Done XGBoost | MAE: {metrics_xgb['MAE']:.4f}, RMSE: {metrics_xgb['RMSE']:.4f}")
#
# File c:\My Stuff\Projects\Stock Forecast App\stock-forecast-app\src\models\xgboost.py:132, in XGBoostModel(train_df, test_df, save_dir, HORIZON, n_iter, cv_splits)
#     130 # ---------------- Prediction & Metrics ----------------
#     131 y_pred = best_model.predict(X_test)
# --> 132 mae = mean_absolute_error(y_test, y_pred)
#     133 rmse = np.sqrt(mean_squared_error(y_test, y_pred))
#     134 metrics = {"MAE": mae, "RMSE": rmse}
#
# File c:\Users\jayan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\jayan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:284, in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     228 """Mean absolute error regression loss.
#     229
#     230 The mean absolute error is a non-negative floating point value, where best value
#    (...)
#     279 0.85...
#     280 """
#     281 xp, _ = get_namespace(y_true, y_pred, sample_weight, multioutput)
#     283 _, y_true, y_pred, sample_weight, multioutput = (
# --> 284     _check_reg_targets_with_floating_dtype(
#     285         y_true, y_pred, sample_weight, multioutput, xp=xp
#     286     )
#     287 )
#     289 output_errors = _average(
#     290     xp.abs(y_pred - y_true), weights=sample_weight, axis=0, xp=xp
#     291 )
#     292 if isinstance(multioutput, str):
#
# File c:\Users\jayan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:209, in _check_reg_targets_with_floating_dtype(y_true, y_pred, sample_weight, multioutput, xp)
#     160 """Ensures y_true, y_pred, and sample_weight correspond to same regression task.
#     161
#     162 Extends `_check_reg_targets` by automatically selecting a suitable floating-point
#    (...)
#     205     correct keyword.
#     206 """
#     207 dtype_name = _find_matching_floating_dtype(y_true, y_pred, sample_weight, xp=xp)
# --> 209 y_type, y_true, y_pred, sample_weight, multioutput = _check_reg_targets(
#     210     y_true, y_pred, sample_weight, multioutput, dtype=dtype_name, xp=xp
#     211 )
#     213 return y_type, y_true, y_pred, sample_weight, multioutput
#
# File c:\Users\jayan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:115, in _check_reg_targets(y_true, y_pred, sample_weight, multioutput, dtype, xp)
#     112 xp, _ = get_namespace(y_true, y_pred, multioutput, xp=xp)
#     114 check_consistent_length(y_true, y_pred, sample_weight)
# --> 115 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     116 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     117 if sample_weight is not None:
#
# File c:\Users\jayan\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1128, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1126     n_samples = _num_samples(array)
#    1127     if n_samples < ensure_min_samples:
# -> 1128         raise ValueError(
#    1129             "Found array with %d sample(s) (shape=%s) while a"
#    1130             " minimum of %d is required%s."
#    1131             % (n_samples, array.shape, ensure_min_samples, context)
#    1132         )
#    1134 if ensure_min_features > 0 and array.ndim == 2:
#    1135     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 30)) while a minimum of 1 is required.
