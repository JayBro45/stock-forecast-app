# %%
import sys
import os
import pandas as pd

# %%
# Add project root to sys.path
sys.path.append(os.path.abspath(".."))

from src.utils.logger import evaluate_all_models

# %%
df = pd.read_csv("../data/processed/MSFT_clean.csv", parse_dates=["Date"])

# %%
split_idx = -30
train = df.iloc[:split_idx].copy()
test = df.iloc[split_idx:].copy()

# %%
results_df = evaluate_all_models(train, test, save_dir="../src/models/metrics")
# Out:
# ⚡ Running Naive Baseline...
# 💾 Model saved at: ../src/models/metrics\naive\naive_baseline_model.pkl
# ✅ Done Naive Baseline | MAE: 8.0737, RMSE: 10.3880
#
# ⚡ Running ARIMA...
# WARNING - (NP.forecaster.fit) - When Global modeling with local normalization, metrics are displayed in normalized scale.
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 96.17% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - B
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# 💾 ARIMA model saved at: ../src/models/metrics\arima\arima_model.pkl
# ✅ Done ARIMA | MAE: 30.7560, RMSE: 37.4537
#
# ⚡ Running NeuralProphet...
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# WARNING - (NP.config.set_lr_finder_args) - Learning rate finder: The number of batches (61) is too small than the required number                     for the learning rate finder (232). The results might not be optimal.
# Finding best initial lr:   0%|          | 0/232 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 96.17% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - B
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 96.667% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - B
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 96.667% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - B
# Predicting: 61it [00:00, ?it/s]
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# 💾 Model saved at: ../src/models/metrics\neuralprophet\neuralprophet_model.pkl
# ✅ Done NeuralProphet | MAE: 39.0315, RMSE: 40.9467
#
# ⚡ Running XGBoost...
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# Metrics (TEST t+1): MAE=6.9261, RMSE=9.5687
# 💾 Saved XGBoost model at ../src/models/metrics\xgboost\xgboost.joblib
# ✅ Done XGBoost | MAE: 6.9261, RMSE: 9.5687
#
# ⚡ Running LSTM...
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0134
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0025
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0023
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0023
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0021
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0018
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0019
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0017
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0021
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0018
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0017
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0017
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0016
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0016
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0014
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0015
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0017
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0014
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0013
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0012
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0012
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0012
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0012
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0011
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0011
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0011
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0010
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0011
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0011
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0012
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.4062e-04
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.7756e-04
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.8177e-04
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.1960e-04
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.8341e-04
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.8292e-04
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.1450e-04
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.0604e-04
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.1830e-04
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.2306e-04
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.4172e-04
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.9942e-04
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.0732e-04
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.2515e-04
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.8526e-04
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.8507e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Done LSTM | MAE: 8.4849, RMSE: 10.2669
#
# 📊 Collecting metrics...
# 📁 Metrics saved to ../src/models/metrics\metrics/model_comparison.csv
# 📈 Comparison plot saved to ../src/models/metrics\metrics/comparison_plot.png
#
# 🏆 Leaderboard (sorted by RMSE):
#                       MAE       RMSE
# XGBoost          6.926054   9.568671
# LSTM             8.484946  10.266860
# Naive Baseline   8.073674  10.387985
# ARIMA           30.755957  37.453741
# NeuralProphet   39.031466  40.946680
